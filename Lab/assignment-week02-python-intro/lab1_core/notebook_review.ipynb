# %% [markdown]
# # Lab 1 Core: AI Code Review Challenge
#
# 在这个 Notebook 中，我们将运行 AI 生成的“毒药代码”，复现并分析其中的物理谬误。
#
# **小组任务**：
# 1. 运行代码，观察诡异现象。
# 2. 记录 Bug 现象到实验报告中。
# 3. 使用 Prompt 让 AI 解释错误原因。

# %%
import sys
import os
# 导入 src 目录
sys.path.append('src')
from bad_particle import simulate_two_particles

# %% [markdown]
# ## 1. 运行毒药代码
#
# 请仔细观察下方的输出结果。重点关注：
# 1. `p1` 的位置是否发生了非预期的变化？
# 2. 粒子的运动轨迹是否合理？

# %%
try:
    simulate_two_particles()
except Exception as e:
    print(f"💥 运行报错: {e}")

# %% [markdown]
# ## 2. 你的分析
#
# 请在此处用 Markdown 记录你观察到的现象（也可以截图粘贴）：
#
# > *在此处填写你的观察结果...*
